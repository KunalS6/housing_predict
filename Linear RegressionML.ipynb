# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('HousingData.csv')

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
dataset.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
dataset.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
def fillblank(table_name,column_name):
    mean_val=table_name[column_name].mean()
    return table_name[column_name].fillna(value=mean_val,inplace=True)

def relation_variable(table_name,col1_name,col1_label,col2_name,col_label):
    plt.scatter(table_name[col1_name],table_name[col2_name])
    plt.xlabel(col1_label)
    plt.ylabel(col_label)
    return plt.show()
 
def regression_plot(table_name,col1,col2):
    return sns.regplot(x=col1,y=col2,data=table_name)

# %%
fillblank(dataset,'CRIM')
fillblank(dataset,'ZN')
fillblank(dataset,'INDUS')
fillblank(dataset,'CHAS')
fillblank(dataset,'AGE')
fillblank(dataset,'LSTAT')

# %%
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.182930  0.391161 -0.052223  0.410377 -0.215434  0.344934
# ZN      -0.182930  1.000000 -0.513336 -0.036147 -0.502287  0.316550 -0.541274
# INDUS    0.391161 -0.513336  1.000000  0.058035  0.740965 -0.381457  0.614592
# CHAS    -0.052223 -0.036147  0.058035  1.000000  0.073286  0.102284  0.075206
# NOX      0.410377 -0.502287  0.740965  0.073286  1.000000 -0.302188  0.711461
# RM      -0.215434  0.316550 -0.381457  0.102284 -0.302188  1.000000 -0.241351
# AGE      0.344934 -0.541274  0.614592  0.075206  0.711461 -0.241351  1.000000
# DIS     -0.366523  0.638388 -0.699639 -0.091680 -0.769230  0.205246 -0.724353
# RAD      0.608886 -0.306316  0.593176  0.001425  0.611441 -0.209847  0.449989
# TAX      0.566528 -0.308334  0.716062 -0.031483  0.668023 -0.292048  0.500589
# PTRATIO  0.273384 -0.403085  0.384806 -0.109310  0.188933 -0.355501  0.262723
# ...

# %%
relation_variable(dataset,'CRIM','CRIME','MEDV','values')

# %%
relation_variable(dataset,'RM','Avg.Rooms','MEDV','values')

# %%
def regression_plot(table_name,col1,col2):
    return sns.regplot(x=col1,y=col2,data=table_name)

# %%
regression_plot(dataset,'RM','MEDV')
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %%
regression_plot(dataset,'LSTAT','MEDV')
# Out:
# <Axes: xlabel='LSTAT', ylabel='MEDV'>

# %%
regression_plot(dataset,'CHAS','MEDV')
# Out:
# <Axes: xlabel='CHAS', ylabel='MEDV'>

# %%
regression_plot(dataset,'PTRATIO','MEDV')
# Out:
# <Axes: xlabel='PTRATIO', ylabel='MEDV'>

# %%
X=dataset.iloc[:,:-1]

# %%
y=dataset.iloc[:,-1]

# %%
#train test split
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(reg.coef_)
# Out:
# [-0.95689125  0.76564769 -0.0275685   0.99758886 -1.73502958  3.0700712
#  -0.77852723 -3.16148806  1.62771195 -1.11340588 -2.02547903  1.03592543
#  -3.29752116]

# %%
print(reg.intercept_)
# Out:
# 22.970796460176988

# %%
#which param used in the model
reg.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
#predict the data
reg_pred=reg.predict(X_test)

# %%
plt.scatter(y_test,reg_pred)

# %%
#residual 
sns.displot(y_test-reg_pred,kind='kde')

# %%
residual=y_test-reg_pred

# %%
plt.scatter(reg_pred,residual)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
print('MAE: ',mean_absolute_error(y_test,reg_pred))
print('MSE: ',mean_squared_error(y_test,reg_pred))
print('RMSE: ',np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# MAE:  3.1289564965046806
# MSE:  21.0470439572703
# RMSE:  4.587705740048102

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
#more toward the 1 more better for the model
# Out:
# 0.7218887579855516

# %%
adjusted_r2=1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
adjusted_r2
#that needs to be less than r2
# Out:
# 0.6982583910170037

# %% [markdown]
# ##testing

# %%
test_data_x=dataset.iloc[:,:-1]
test_data_y=dataset.iloc[:,-1]

# %%
test_data_x.values[0].reshape(1,-1).shape
# Out:
# (1, 13)

# %%
reg.predict(test_data_x.values[9].reshape(1,-1))
#the resaon its coming negative as we are not doing standard scaler
# Out:
# array([-62.66411318])

# %%
scaler.transform(test_data_x.values[9].reshape(1,-1))
# Out:
# /Applications/Python/anaconda3/envs/housingPrice/lib/python3.8/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.4198247 ,  0.03288813, -0.48889282, -0.02717828, -0.28506678,
#         -0.44927633,  0.62776993,  1.32140055, -0.51803062, -0.59090191,
#         -1.36536677,  0.31963939,  0.64881286]])

# %%
reg.predict(scaler.transform(test_data_x.values[9].reshape(1,-1)))
#now the vlaues are coming correctly
# Out:
# /Applications/Python/anaconda3/envs/housingPrice/lib/python3.8/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([18.60490924])

# %%
import pickle
pickle.dump(reg,open('regmodel.pkl','wb'))

# %%
picked_model=pickle.load(open('regmodel.pkl','rb'))

# %%
picked_model.predict(scaler.transform(test_data_x.values[9].reshape(1,-1)))
# Out:
# /Applications/Python/anaconda3/envs/housingPrice/lib/python3.8/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([18.60490924])
